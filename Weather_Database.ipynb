# %%
# Import the dependencies.
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np

# %%
# Create a set of random latitude and longitude combinations.
lats = np.random.uniform(low=-90.000, high=90.000, size=2000)
lngs = np.random.uniform(low=-180.000, high=180.000, size=2000)
lat_lngs = zip(lats, lngs)
lat_lngs

# %%
# Add the latitudes and longitudes to a list.
coordinates = list(lat_lngs)

# %%
# Use the citipy module to determine city based on latitude and longitude.
from citipy import citipy

# %%
# Create a list for holding the cities.
cities = []

# Identify the nearest city for each latitude and longitude combination.
for coordinate in coordinates:
    city = citipy.nearest_city(coordinate[0], coordinate[1]).city_name
    
    # If the city is unique, then we will add it to the cities list.
    if city not in cities:
        cities.append(city)
        
# Print the city count to confirm sufficient count.
len(cities)
# Out:
# 766

# %%
# Import the requests library.
import requests

# Import Api key
from config import open_weather_api_key

# Import the time library and the datetime module from the datetime library 
import time
from datetime import datetime

#set up the base url 
url = "http://api.openweathermap.org/data/2.5/weather?units=Imperial&appid=" + open_weather_api_key
print(url)
# Out:
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&appid=a1059d16fb4d59b95ddb40d8b99e62e7

# %%
# Create an empty list to hold the weather data.
city_data = []

# Print the beginning of the logging.
print("Beginning Data Retrieval     ")
print("-----------------------------")

# Create counters.
record_count = 1
set_count = 1

# Loop through all the cities in the list.
for i, city in enumerate (cities):
    
    # Group cities in sets of 50 for logging purposes.
    if (i % 50 == 0 and i >= 50):
        set_count += 1
        record_count = 1
        #time.sleep(60)
    
    # Create endpoint URL with each city.
    city_url = url + "&q=" + city.replace(" ", "+")
    
    # Log the URL, record, and set numbers and the city.
    print(f"Processing Record{record_count} of Set {set_count} | {city}")
    
    # Add 1 to the record count.
    record_count += 1
    
    # Run an API request for each of the cities.
    try: 
        # Parse the JSON and retrieve data.
        city_weather = requests.get(city_url).json()
         # Parse out the needed data.
        city_lat = city_weather["coord"]["lat"]
        city_lng = city_weather["coord"]["lon"]
        city_max_temp = city_weather["main"]["temp_max"]
        city_humidity = city_weather["main"]["humidity"]
        city_clouds = city_weather["clouds"]["all"]
        city_wind = city_weather["wind"]["speed"]
        city_country = city_weather["sys"]["country"]
        description = city_weather["weather"][0]["description"]
        # Convert the date to ISO standard.
        city_date = datetime.utcfromtimestamp(city_weather["dt"]).strftime('%Y-%m-%d %H:%M:%S')
        # Append the city information into city_data list.
        city_data.append({"City": city.title(),
                          "Country": city_country,
                          "Lat": city_lat,
                          "Lng": city_lng,
                          "Max Temp": city_max_temp,
                          "Humidity": city_humidity,
                          "Cloudiness": city_clouds,
                          "Wind Speed": city_wind,
                          "Current Description": description})

    # If an error is experienced, skip the city.
    except:
        print("City not found. Skipping...")
        pass

# Indicate that Data Loading is complete.
print("-----------------------------")
print("Data Retrieval Complete      ")
print("-----------------------------")
# Out:
# Beginning Data Retrieval
# -----------------------------
# Processing Record1 of Set 1 | arraial do cabo
# Processing Record2 of Set 1 | cape town
# Processing Record3 of Set 1 | souillac
# Processing Record4 of Set 1 | albany
# Processing Record5 of Set 1 | stoyba
# City not found. Skipping...
# Processing Record6 of Set 1 | bredasdorp
# Processing Record7 of Set 1 | buraydah
# Processing Record8 of Set 1 | clyde river
# Processing Record9 of Set 1 | chuy
# Processing Record10 of Set 1 | margate
# Processing Record11 of Set 1 | norman wells
# Processing Record12 of Set 1 | provideniya
# Processing Record13 of Set 1 | kaitangata
# Processing Record14 of Set 1 | busselton
# Processing Record15 of Set 1 | ponta do sol
# Processing Record16 of Set 1 | punta arenas
# Processing Record17 of Set 1 | butaritari
# Processing Record18 of Set 1 | gorontalo
# Processing Record19 of Set 1 | portland
# Processing Record20 of Set 1 | tuatapere
# Processing Record21 of Set 1 | port alfred
# Processing Record22 of Set 1 | nikolskoye
# Processing Record23 of Set 1 | karasjok
# Processing Record24 of Set 1 | jamestown
# Processing Record25 of Set 1 | charters towers
# Processing Record26 of Set 1 | ostrovnoy
# Processing Record27 of Set 1 | puri
# Processing Record28 of Set 1 | illoqqortoormiut
# City not found. Skipping...
# Processing Record29 of Set 1 | hermanus
# Processing Record30 of Set 1 | machali
# Processing Record31 of Set 1 | hofn
# Processing Record32 of Set 1 | salalah
# Processing Record33 of Set 1 | xinan
# Processing Record34 of Set 1 | maxixe
# Processing Record35 of Set 1 | almeirim
# Processing Record36 of Set 1 | moron
# Processing Record37 of Set 1 | torbay
# Processing Record38 of Set 1 | vanimo
# Processing Record39 of Set 1 | rikitea
# Processing Record40 of Set 1 | lagoa
# Processing Record41 of Set 1 | saskylakh
# Processing Record42 of Set 1 | acapulco
# Processing Record43 of Set 1 | vaini
# Processing Record44 of Set 1 | thompson
# Processing Record45 of Set 1 | mocambique
# City not found. Skipping...
# Processing Record46 of Set 1 | ushuaia
# Processing Record47 of Set 1 | chara
# Processing Record48 of Set 1 | kolokani
# Processing Record49 of Set 1 | hobart
# Processing Record50 of Set 1 | yashan
# Processing Record1 of Set 2 | koster
# Processing Record2 of Set 2 | tura
# Processing Record3 of Set 2 | litoral del san juan
# City not found. Skipping...
# Processing Record4 of Set 2 | alta floresta
# Processing Record5 of Set 2 | palmer
# Processing Record6 of Set 2 | korla
# Processing Record7 of Set 2 | hilo
# Processing Record8 of Set 2 | bolungarvik
# City not found. Skipping...
# Processing Record9 of Set 2 | tuktoyaktuk
# Processing Record10 of Set 2 | new norfolk
# Processing Record11 of Set 2 | sinazongwe
# Processing Record12 of Set 2 | zhigansk
# Processing Record13 of Set 2 | diego de almagro
# Processing Record14 of Set 2 | tazovskiy
# Processing Record15 of Set 2 | kodiak
# Processing Record16 of Set 2 | east london
# Processing Record17 of Set 2 | meulaboh
# Processing Record18 of Set 2 | port lincoln
# Processing Record19 of Set 2 | los llanos de aridane
# Processing Record20 of Set 2 | castro
# Processing Record21 of Set 2 | laguna de perlas
# Processing Record22 of Set 2 | tiksi
# Processing Record23 of Set 2 | pasni
# Processing Record24 of Set 2 | omaruru
# Processing Record25 of Set 2 | coari
# Processing Record26 of Set 2 | pisco
# Processing Record27 of Set 2 | fayaoue
# Processing Record28 of Set 2 | okha
# Processing Record29 of Set 2 | nizhneyansk
# City not found. Skipping...
# Processing Record30 of Set 2 | tsihombe
# City not found. Skipping...
# Processing Record31 of Set 2 | zhanakorgan
# Processing Record32 of Set 2 | bridlington
# Processing Record33 of Set 2 | ust-kamchatsk
# City not found. Skipping...
# Processing Record34 of Set 2 | maryville
# Processing Record35 of Set 2 | magistralnyy
# Processing Record36 of Set 2 | amahai
# Processing Record37 of Set 2 | almaznyy
# Processing Record38 of Set 2 | mahebourg
# Processing Record39 of Set 2 | klaksvik
# Processing Record40 of Set 2 | sao filipe
# Processing Record41 of Set 2 | mataura
# Processing Record42 of Set 2 | avarua
# Processing Record43 of Set 2 | maniitsoq
# Processing Record44 of Set 2 | vila franca do campo
# Processing Record45 of Set 2 | port elizabeth
# Processing Record46 of Set 2 | galesong
# Processing Record47 of Set 2 | high rock
# Processing Record48 of Set 2 | alghero
# Processing Record49 of Set 2 | maragogi
# Processing Record50 of Set 2 | ocean city
# Processing Record1 of Set 3 | faanui
# Processing Record2 of Set 3 | bluff
# Processing Record3 of Set 3 | pevek
# Processing Record4 of Set 3 | juneau
# Processing Record5 of Set 3 | valentin gomez farias
# Processing Record6 of Set 3 | mar del plata
# Processing Record7 of Set 3 | sangre grande
# Processing Record8 of Set 3 | noumea
# Processing Record9 of Set 3 | kyren
# Processing Record10 of Set 3 | balkhash
# Processing Record11 of Set 3 | avera
# Processing Record12 of Set 3 | baykit
# Processing Record13 of Set 3 | palabuhanratu
# City not found. Skipping...
# Processing Record14 of Set 3 | saint-joseph
# Processing Record15 of Set 3 | maun
# Processing Record16 of Set 3 | orange cove
# Processing Record17 of Set 3 | coihaique
# Processing Record18 of Set 3 | taolanaro
# City not found. Skipping...
# Processing Record19 of Set 3 | tilichiki
# Processing Record20 of Set 3 | lewistown
# Processing Record21 of Set 3 | rocha
# Processing Record22 of Set 3 | sur
# Processing Record23 of Set 3 | touros
# Processing Record24 of Set 3 | kavaratti
# Processing Record25 of Set 3 | karratha
# Processing Record26 of Set 3 | bilma
# Processing Record27 of Set 3 | barentsburg
# City not found. Skipping...
# Processing Record28 of Set 3 | oistins
# Processing Record29 of Set 3 | qaanaaq
# Processing Record30 of Set 3 | hithadhoo
# Processing Record31 of Set 3 | hambantota
# Processing Record32 of Set 3 | yabelo
# Processing Record33 of Set 3 | puerto ayora
# Processing Record34 of Set 3 | arkhangelsk
# Processing Record35 of Set 3 | jilove
# Processing Record36 of Set 3 | saint-philippe
# Processing Record37 of Set 3 | waingapu
# Processing Record38 of Set 3 | kapaa
# Processing Record39 of Set 3 | atuona
# Processing Record40 of Set 3 | tiznit
# Processing Record41 of Set 3 | georgetown
# Processing Record42 of Set 3 | fort nelson
# Processing Record43 of Set 3 | lompoc
# Processing Record44 of Set 3 | baherden
# Processing Record45 of Set 3 | necochea
# Processing Record46 of Set 3 | samatau
# City not found. Skipping...
# Processing Record47 of Set 3 | araouane
# Processing Record48 of Set 3 | mys shmidta
# City not found. Skipping...
# Processing Record49 of Set 3 | rio grande
# Processing Record50 of Set 3 | tasiilaq
# Processing Record1 of Set 4 | chifeng
# Processing Record2 of Set 4 | mangrol
# Processing Record3 of Set 4 | iqaluit
# Processing Record4 of Set 4 | monrovia
# Processing Record5 of Set 4 | codrington
# Processing Record6 of Set 4 | lodwar
# Processing Record7 of Set 4 | radviliskis
# Processing Record8 of Set 4 | yar-sale
# Processing Record9 of Set 4 | vostok
# Processing Record10 of Set 4 | kabanjahe
# Processing Record11 of Set 4 | yerbogachen
# Processing Record12 of Set 4 | teahupoo
# Processing Record13 of Set 4 | altamira
# Processing Record14 of Set 4 | panaba
# Processing Record15 of Set 4 | saldanha
# Processing Record16 of Set 4 | guarapari
# Processing Record17 of Set 4 | bonavista
# Processing Record18 of Set 4 | hue
# Processing Record19 of Set 4 | faya
# Processing Record20 of Set 4 | valparaiso
# Processing Record21 of Set 4 | reporoa
# Processing Record22 of Set 4 | barrow
# Processing Record23 of Set 4 | severo-kurilsk
# Processing Record24 of Set 4 | sao joao da barra
# Processing Record25 of Set 4 | sitka
# Processing Record26 of Set 4 | hamilton
# Processing Record27 of Set 4 | college
# Processing Record28 of Set 4 | port hedland
# Processing Record29 of Set 4 | san joaquin
# Processing Record30 of Set 4 | dakar
# Processing Record31 of Set 4 | aykhal
# Processing Record32 of Set 4 | saleaula
# City not found. Skipping...
# Processing Record33 of Set 4 | louisbourg
# City not found. Skipping...
# Processing Record34 of Set 4 | saint anthony
# Processing Record35 of Set 4 | lukulu
# Processing Record36 of Set 4 | acari
# Processing Record37 of Set 4 | namibe
# Processing Record38 of Set 4 | vysokovsk
# Processing Record39 of Set 4 | ambodifototra
# City not found. Skipping...
# Processing Record40 of Set 4 | yellowknife
# Processing Record41 of Set 4 | cabo san lucas
# Processing Record42 of Set 4 | khonuu
# City not found. Skipping...
# Processing Record43 of Set 4 | zhanaozen
# Processing Record44 of Set 4 | takaungu
# Processing Record45 of Set 4 | innisfail
# Processing Record46 of Set 4 | carballo
# Processing Record47 of Set 4 | tabiauea
# City not found. Skipping...
# Processing Record48 of Set 4 | victoria point
# Processing Record49 of Set 4 | cockburn town
# Processing Record50 of Set 4 | saint george
# Processing Record1 of Set 5 | tabou
# Processing Record2 of Set 5 | cidreira
# Processing Record3 of Set 5 | jiroft
# City not found. Skipping...
# Processing Record4 of Set 5 | saint-augustin
# Processing Record5 of Set 5 | terrace
# Processing Record6 of Set 5 | gambela
# Processing Record7 of Set 5 | dikson
# Processing Record8 of Set 5 | kindu
# Processing Record9 of Set 5 | bethel
# Processing Record10 of Set 5 | fairbanks
# Processing Record11 of Set 5 | port hawkesbury
# Processing Record12 of Set 5 | amderma
# City not found. Skipping...
# Processing Record13 of Set 5 | soyo
# Processing Record14 of Set 5 | xinmin
# Processing Record15 of Set 5 | lavrentiya
# Processing Record16 of Set 5 | san jose
# Processing Record17 of Set 5 | saint-pierre
# Processing Record18 of Set 5 | yellandu
# Processing Record19 of Set 5 | olinda
# Processing Record20 of Set 5 | moose factory
# Processing Record21 of Set 5 | cotonou
# Processing Record22 of Set 5 | chitral
# Processing Record23 of Set 5 | sioux lookout
# Processing Record24 of Set 5 | vestmannaeyjar
# Processing Record25 of Set 5 | adrar
# Processing Record26 of Set 5 | myitkyina
# Processing Record27 of Set 5 | petropavlovsk-kamchatskiy
# Processing Record28 of Set 5 | tucuman
# Processing Record29 of Set 5 | cherskiy
# Processing Record30 of Set 5 | taltal
# Processing Record31 of Set 5 | guerrero negro
# Processing Record32 of Set 5 | kruisfontein
# Processing Record33 of Set 5 | ambatondrazaka
# Processing Record34 of Set 5 | northam
# Processing Record35 of Set 5 | lappeenranta
# Processing Record36 of Set 5 | ust-kuyga
# Processing Record37 of Set 5 | namie
# Processing Record38 of Set 5 | sambava
# Processing Record39 of Set 5 | hoi an
# Processing Record40 of Set 5 | alofi
# Processing Record41 of Set 5 | broome
# Processing Record42 of Set 5 | attawapiskat
# City not found. Skipping...
# Processing Record43 of Set 5 | parkes
# Processing Record44 of Set 5 | carnarvon
# Processing Record45 of Set 5 | mercedes
# Processing Record46 of Set 5 | honningsvag
# Processing Record47 of Set 5 | sept-iles
# Processing Record48 of Set 5 | chokurdakh
# Processing Record49 of Set 5 | vaitupu
# City not found. Skipping...
# Processing Record50 of Set 5 | esperance
# Processing Record1 of Set 6 | buenos aires
# Processing Record2 of Set 6 | mount isa
# Processing Record3 of Set 6 | katsuura
# Processing Record4 of Set 6 | tommot
# Processing Record5 of Set 6 | geraldton
# Processing Record6 of Set 6 | port shepstone
# Processing Record7 of Set 6 | zanjan
# Processing Record8 of Set 6 | tocopilla
# Processing Record9 of Set 6 | grand river south east
# City not found. Skipping...
# Processing Record10 of Set 6 | datong
# Processing Record11 of Set 6 | betul
# Processing Record12 of Set 6 | fortuna
# Processing Record13 of Set 6 | udachnyy
# Processing Record14 of Set 6 | springbok
# Processing Record15 of Set 6 | muriti
# Processing Record16 of Set 6 | tarsus
# Processing Record17 of Set 6 | chupa
# Processing Record18 of Set 6 | natal
# Processing Record19 of Set 6 | lucapa
# Processing Record20 of Set 6 | ornes
# Processing Record21 of Set 6 | kamenskoye
# City not found. Skipping...
# Processing Record22 of Set 6 | hasaki
# Processing Record23 of Set 6 | amapa
# Processing Record24 of Set 6 | los algarrobos
# Processing Record25 of Set 6 | san luis
# Processing Record26 of Set 6 | bermejo
# Processing Record27 of Set 6 | haines junction
# Processing Record28 of Set 6 | anloga
# Processing Record29 of Set 6 | rantepao
# Processing Record30 of Set 6 | vestmanna
# Processing Record31 of Set 6 | san quintin
# Processing Record32 of Set 6 | krasnouralsk
# Processing Record33 of Set 6 | andreapol
# Processing Record34 of Set 6 | bataraza
# City not found. Skipping...
# Processing Record35 of Set 6 | fukue
# Processing Record36 of Set 6 | chute-aux-outardes
# Processing Record37 of Set 6 | goderich
# Processing Record38 of Set 6 | sol-iletsk
# Processing Record39 of Set 6 | morgan city
# Processing Record40 of Set 6 | wewak
# Processing Record41 of Set 6 | tungor
# Processing Record42 of Set 6 | sorland
# Processing Record43 of Set 6 | alibag
# Processing Record44 of Set 6 | ukiah
# Processing Record45 of Set 6 | trincomalee
# Processing Record46 of Set 6 | basco
# Processing Record47 of Set 6 | poplar bluff
# Processing Record48 of Set 6 | vodnyy
# Processing Record49 of Set 6 | oranjemund
# Processing Record50 of Set 6 | aklavik
# Processing Record1 of Set 7 | victoria
# Processing Record2 of Set 7 | chapais
# Processing Record3 of Set 7 | dunbar
# Processing Record4 of Set 7 | praia
# Processing Record5 of Set 7 | bagotville
# Processing Record6 of Set 7 | bilibino
# Processing Record7 of Set 7 | zalantun
# Processing Record8 of Set 7 | san francisco
# Processing Record9 of Set 7 | contamana
# Processing Record10 of Set 7 | najran
# Processing Record11 of Set 7 | bay roberts
# Processing Record12 of Set 7 | padang
# Processing Record13 of Set 7 | jumla
# Processing Record14 of Set 7 | shingu
# Processing Record15 of Set 7 | sinnamary
# Processing Record16 of Set 7 | maba
# Processing Record17 of Set 7 | pontalina
# Processing Record18 of Set 7 | xining
# Processing Record19 of Set 7 | warqla
# City not found. Skipping...
# Processing Record20 of Set 7 | port-gentil
# Processing Record21 of Set 7 | sentyabrskiy
# City not found. Skipping...
# Processing Record22 of Set 7 | sokoto
# Processing Record23 of Set 7 | moctezuma
# Processing Record24 of Set 7 | front royal
# Processing Record25 of Set 7 | atar
# Processing Record26 of Set 7 | ruian
# City not found. Skipping...
# Processing Record27 of Set 7 | manzanillo
# Processing Record28 of Set 7 | khatanga
# Processing Record29 of Set 7 | kalemie
# Processing Record30 of Set 7 | ngunguru
# Processing Record31 of Set 7 | riyadh
# Processing Record32 of Set 7 | westport
# Processing Record33 of Set 7 | ozgon
# City not found. Skipping...
# Processing Record34 of Set 7 | north bend
# Processing Record35 of Set 7 | ilinskiy
# Processing Record36 of Set 7 | puerto quijarro
# Processing Record37 of Set 7 | wajid
# Processing Record38 of Set 7 | sistranda
# Processing Record39 of Set 7 | torit
# Processing Record40 of Set 7 | fare
# Processing Record41 of Set 7 | qui nhon
# Processing Record42 of Set 7 | omsukchan
# Processing Record43 of Set 7 | drexel heights
# Processing Record44 of Set 7 | khoy
# Processing Record45 of Set 7 | brigantine
# Processing Record46 of Set 7 | saint-francois
# Processing Record47 of Set 7 | fethiye
# Processing Record48 of Set 7 | srivardhan
# Processing Record49 of Set 7 | malakal
# Processing Record50 of Set 7 | panama city
# Processing Record1 of Set 8 | wabana
# Processing Record2 of Set 8 | isangel
# Processing Record3 of Set 8 | honiara
# Processing Record4 of Set 8 | veraval
# Processing Record5 of Set 8 | jaru
# Processing Record6 of Set 8 | lata
# Processing Record7 of Set 8 | raudeberg
# Processing Record8 of Set 8 | dunedin
# Processing Record9 of Set 8 | ponta delgada
# Processing Record10 of Set 8 | yulara
# Processing Record11 of Set 8 | mount gambier
# Processing Record12 of Set 8 | dubreka
# Processing Record13 of Set 8 | kurri kurri
# Processing Record14 of Set 8 | sangmelima
# Processing Record15 of Set 8 | puerto narino
# Processing Record16 of Set 8 | borisoglebskiy
# Processing Record17 of Set 8 | florence
# Processing Record18 of Set 8 | umba
# Processing Record19 of Set 8 | turukhansk
# Processing Record20 of Set 8 | jadu
# Processing Record21 of Set 8 | pandan
# Processing Record22 of Set 8 | siguiri
# Processing Record23 of Set 8 | camacha
# Processing Record24 of Set 8 | port macquarie
# Processing Record25 of Set 8 | kearney
# Processing Record26 of Set 8 | gat
# Processing Record27 of Set 8 | atlantic city
# Processing Record28 of Set 8 | formosa
# Processing Record29 of Set 8 | kegayli
# City not found. Skipping...
# Processing Record30 of Set 8 | saryg-sep
# Processing Record31 of Set 8 | samalaeulu
# City not found. Skipping...
# Processing Record32 of Set 8 | arroyo
# Processing Record33 of Set 8 | tsogni
# Processing Record34 of Set 8 | aden
# Processing Record35 of Set 8 | howard springs
# Processing Record36 of Set 8 | aksu
# Processing Record37 of Set 8 | bambous virieux
# Processing Record38 of Set 8 | upernavik
# Processing Record39 of Set 8 | pimenta bueno
# Processing Record40 of Set 8 | puerto del rosario
# Processing Record41 of Set 8 | morden
# Processing Record42 of Set 8 | walvis bay
# Processing Record43 of Set 8 | abu samrah
# Processing Record44 of Set 8 | boende
# Processing Record45 of Set 8 | bima
# Processing Record46 of Set 8 | staryy nadym
# Processing Record47 of Set 8 | abu dhabi
# Processing Record48 of Set 8 | sherghati
# Processing Record49 of Set 8 | mitu
# Processing Record50 of Set 8 | poopo
# Processing Record1 of Set 9 | bemidji
# Processing Record2 of Set 9 | kavieng
# Processing Record3 of Set 9 | half moon bay
# Processing Record4 of Set 9 | lukovetskiy
# Processing Record5 of Set 9 | mehamn
# Processing Record6 of Set 9 | sayyan
# Processing Record7 of Set 9 | mazagao
# Processing Record8 of Set 9 | babanusah
# City not found. Skipping...
# Processing Record9 of Set 9 | abha
# Processing Record10 of Set 9 | ribeira grande
# Processing Record11 of Set 9 | porto belo
# Processing Record12 of Set 9 | neuquen
# Processing Record13 of Set 9 | lugovoy
# Processing Record14 of Set 9 | kurumkan
# Processing Record15 of Set 9 | dwarka
# Processing Record16 of Set 9 | siavonga
# Processing Record17 of Set 9 | le port
# Processing Record18 of Set 9 | baruun-urt
# Processing Record19 of Set 9 | barcelona
# Processing Record20 of Set 9 | marcona
# City not found. Skipping...
# Processing Record21 of Set 9 | paamiut
# Processing Record22 of Set 9 | aviles
# Processing Record23 of Set 9 | bongaree
# Processing Record24 of Set 9 | brownsville
# Processing Record25 of Set 9 | roald
# Processing Record26 of Set 9 | gurupi
# Processing Record27 of Set 9 | manassas park
# Processing Record28 of Set 9 | laguna
# Processing Record29 of Set 9 | zhangye
# Processing Record30 of Set 9 | garowe
# Processing Record31 of Set 9 | fort-shevchenko
# Processing Record32 of Set 9 | leningradskiy
# Processing Record33 of Set 9 | husavik
# Processing Record34 of Set 9 | lebu
# Processing Record35 of Set 9 | ternate
# Processing Record36 of Set 9 | agirish
# Processing Record37 of Set 9 | saurimo
# Processing Record38 of Set 9 | salym
# Processing Record39 of Set 9 | metro
# Processing Record40 of Set 9 | marsa matruh
# Processing Record41 of Set 9 | belushya guba
# City not found. Skipping...
# Processing Record42 of Set 9 | severodvinsk
# Processing Record43 of Set 9 | toppenish
# Processing Record44 of Set 9 | tocache
# Processing Record45 of Set 9 | kohlu
# Processing Record46 of Set 9 | marsh harbour
# Processing Record47 of Set 9 | ust-nera
# Processing Record48 of Set 9 | ballina
# Processing Record49 of Set 9 | ibra
# Processing Record50 of Set 9 | thaba-tseka
# Processing Record1 of Set 10 | partizanskoye
# Processing Record2 of Set 10 | san cristobal
# Processing Record3 of Set 10 | usinsk
# Processing Record4 of Set 10 | kano
# Processing Record5 of Set 10 | pitimbu
# Processing Record6 of Set 10 | ulladulla
# Processing Record7 of Set 10 | airai
# Processing Record8 of Set 10 | palmar
# Processing Record9 of Set 10 | longyearbyen
# Processing Record10 of Set 10 | hovd
# Processing Record11 of Set 10 | rupert
# Processing Record12 of Set 10 | vardo
# Processing Record13 of Set 10 | batagay
# Processing Record14 of Set 10 | gasa
# Processing Record15 of Set 10 | greenwood
# Processing Record16 of Set 10 | ozark
# Processing Record17 of Set 10 | pochutla
# Processing Record18 of Set 10 | byron bay
# Processing Record19 of Set 10 | talnakh
# Processing Record20 of Set 10 | nanortalik
# Processing Record21 of Set 10 | narsaq
# Processing Record22 of Set 10 | orjahovo
# City not found. Skipping...
# Processing Record23 of Set 10 | ayr
# Processing Record24 of Set 10 | tumannyy
# City not found. Skipping...
# Processing Record25 of Set 10 | chicama
# Processing Record26 of Set 10 | auch
# Processing Record27 of Set 10 | grimshaw
# Processing Record28 of Set 10 | kamenka
# Processing Record29 of Set 10 | viligili
# City not found. Skipping...
# Processing Record30 of Set 10 | dudinka
# Processing Record31 of Set 10 | kamina
# Processing Record32 of Set 10 | kachikau
# City not found. Skipping...
# Processing Record33 of Set 10 | morros
# Processing Record34 of Set 10 | atmakur
# Processing Record35 of Set 10 | luderitz
# Processing Record36 of Set 10 | bafoulabe
# Processing Record37 of Set 10 | lasa
# Processing Record38 of Set 10 | ventspils
# Processing Record39 of Set 10 | pampa
# Processing Record40 of Set 10 | beringovskiy
# Processing Record41 of Set 10 | ulaanbaatar
# Processing Record42 of Set 10 | lima
# Processing Record43 of Set 10 | port hardy
# Processing Record44 of Set 10 | samusu
# City not found. Skipping...
# Processing Record45 of Set 10 | macon
# Processing Record46 of Set 10 | bengkulu
# Processing Record47 of Set 10 | lavras
# Processing Record48 of Set 10 | joutseno
# Processing Record49 of Set 10 | varhaug
# Processing Record50 of Set 10 | deep river
# Processing Record1 of Set 11 | samarai
# Processing Record2 of Set 11 | nemuro
# Processing Record3 of Set 11 | umea
# Processing Record4 of Set 11 | moerai
# Processing Record5 of Set 11 | telenesti
# Processing Record6 of Set 11 | kutum
# Processing Record7 of Set 11 | kawalu
# Processing Record8 of Set 11 | novoagansk
# Processing Record9 of Set 11 | belem de sao francisco
# Processing Record10 of Set 11 | kholmogory
# Processing Record11 of Set 11 | riverton
# Processing Record12 of Set 11 | boulogne-sur-mer
# Processing Record13 of Set 11 | havre-saint-pierre
# Processing Record14 of Set 11 | ilulissat
# Processing Record15 of Set 11 | coquimbo
# Processing Record16 of Set 11 | bargal
# City not found. Skipping...
# Processing Record17 of Set 11 | lubuk pakam
# Processing Record18 of Set 11 | liverpool
# Processing Record19 of Set 11 | wagar
# Processing Record20 of Set 11 | tucurui
# Processing Record21 of Set 11 | tautira
# Processing Record22 of Set 11 | san ramon
# Processing Record23 of Set 11 | kuandian
# Processing Record24 of Set 11 | weinan
# Processing Record25 of Set 11 | la ronge
# Processing Record26 of Set 11 | nanakuli
# Processing Record27 of Set 11 | gao
# Processing Record28 of Set 11 | astana
# Processing Record29 of Set 11 | port antonio
# Processing Record30 of Set 11 | koltubanovskiy
# Processing Record31 of Set 11 | chomun
# City not found. Skipping...
# Processing Record32 of Set 11 | dutlwe
# Processing Record33 of Set 11 | brae
# Processing Record34 of Set 11 | cayenne
# Processing Record35 of Set 11 | berbera
# Processing Record36 of Set 11 | kahului
# Processing Record37 of Set 11 | sola
# Processing Record38 of Set 11 | bontang
# Processing Record39 of Set 11 | poso
# Processing Record40 of Set 11 | niceville
# Processing Record41 of Set 11 | ahipara
# Processing Record42 of Set 11 | hire
# City not found. Skipping...
# Processing Record43 of Set 11 | inuvik
# Processing Record44 of Set 11 | muroto
# Processing Record45 of Set 11 | angoche
# Processing Record46 of Set 11 | kenora
# Processing Record47 of Set 11 | cozumel
# Processing Record48 of Set 11 | ayagoz
# Processing Record49 of Set 11 | nantucket
# Processing Record50 of Set 11 | huambo
# Processing Record1 of Set 12 | roma
# Processing Record2 of Set 12 | shache
# Processing Record3 of Set 12 | kabare
# Processing Record4 of Set 12 | west point
# Processing Record5 of Set 12 | mezen
# Processing Record6 of Set 12 | tshikapa
# Processing Record7 of Set 12 | caravelas
# Processing Record8 of Set 12 | agaro
# Processing Record9 of Set 12 | dujuma
# City not found. Skipping...
# Processing Record10 of Set 12 | deputatskiy
# Processing Record11 of Set 12 | flin flon
# Processing Record12 of Set 12 | nabire
# Processing Record13 of Set 12 | rudbar
# Processing Record14 of Set 12 | monroe
# Processing Record15 of Set 12 | alice springs
# Processing Record16 of Set 12 | richards bay
# Processing Record17 of Set 12 | guajara-mirim
# City not found. Skipping...
# Processing Record18 of Set 12 | sao felix do xingu
# Processing Record19 of Set 12 | ulcinj
# Processing Record20 of Set 12 | puerto baquerizo moreno
# Processing Record21 of Set 12 | kaeo
# Processing Record22 of Set 12 | tondano
# Processing Record23 of Set 12 | nerja
# Processing Record24 of Set 12 | kysyl-syr
# Processing Record25 of Set 12 | dasoguz
# Processing Record26 of Set 12 | balabac
# Processing Record27 of Set 12 | hirado
# Processing Record28 of Set 12 | la romana
# Processing Record29 of Set 12 | ancud
# Processing Record30 of Set 12 | vao
# Processing Record31 of Set 12 | peniche
# Processing Record32 of Set 12 | asau
# Processing Record33 of Set 12 | placido de castro
# Processing Record34 of Set 12 | kampene
# Processing Record35 of Set 12 | pravia
# Processing Record36 of Set 12 | bathsheba
# Processing Record37 of Set 12 | bodden town
# Processing Record38 of Set 12 | bandarbeyla
# Processing Record39 of Set 12 | bairiki
# Processing Record40 of Set 12 | thanatpin
# Processing Record41 of Set 12 | jiujiang
# Processing Record42 of Set 12 | pacific grove
# Processing Record43 of Set 12 | tyukalinsk
# Processing Record44 of Set 12 | halalo
# City not found. Skipping...
# Processing Record45 of Set 12 | constitucion
# Processing Record46 of Set 12 | cruzilia
# Processing Record47 of Set 12 | kinel-cherkassy
# Processing Record48 of Set 12 | sarkand
# Processing Record49 of Set 12 | dalbandin
# Processing Record50 of Set 12 | kashirskoye
# Processing Record1 of Set 13 | raymondville
# Processing Record2 of Set 13 | ardistan
# City not found. Skipping...
# Processing Record3 of Set 13 | maceio
# Processing Record4 of Set 13 | tadine
# Processing Record5 of Set 13 | kokuy
# Processing Record6 of Set 13 | estacion coahuila
# Processing Record7 of Set 13 | cascais
# Processing Record8 of Set 13 | maarianhamina
# Processing Record9 of Set 13 | havelock
# Processing Record10 of Set 13 | ruatoria
# City not found. Skipping...
# Processing Record11 of Set 13 | wanaka
# Processing Record12 of Set 13 | borogontsy
# Processing Record13 of Set 13 | kupang
# Processing Record14 of Set 13 | nakhon ratchasima
# Processing Record15 of Set 13 | tiarei
# Processing Record16 of Set 13 | mahibadhoo
# Processing Record17 of Set 13 | egvekinot
# Processing Record18 of Set 13 | nguiu
# City not found. Skipping...
# Processing Record19 of Set 13 | nizhniy tsasuchey
# Processing Record20 of Set 13 | baisha
# Processing Record21 of Set 13 | zhuanghe
# Processing Record22 of Set 13 | pak phanang
# Processing Record23 of Set 13 | gobabis
# Processing Record24 of Set 13 | cockburn harbour
# City not found. Skipping...
# Processing Record25 of Set 13 | along
# Processing Record26 of Set 13 | beloha
# Processing Record27 of Set 13 | cobija
# Processing Record28 of Set 13 | jiwani
# Processing Record29 of Set 13 | baghdad
# Processing Record30 of Set 13 | talah
# City not found. Skipping...
# Processing Record31 of Set 13 | nyurba
# Processing Record32 of Set 13 | mountain home
# Processing Record33 of Set 13 | dongsheng
# Processing Record34 of Set 13 | thinadhoo
# Processing Record35 of Set 13 | dayong
# Processing Record36 of Set 13 | luzhou
# Processing Record37 of Set 13 | bobonong
# City not found. Skipping...
# Processing Record38 of Set 13 | te anau
# Processing Record39 of Set 13 | bereda
# Processing Record40 of Set 13 | mnogovershinnyy
# Processing Record41 of Set 13 | morris
# Processing Record42 of Set 13 | aksarka
# Processing Record43 of Set 13 | hjelset
# Processing Record44 of Set 13 | nexo
# Processing Record45 of Set 13 | pandamatenga
# Processing Record46 of Set 13 | fuxin
# Processing Record47 of Set 13 | carutapera
# Processing Record48 of Set 13 | ngukurr
# City not found. Skipping...
# Processing Record49 of Set 13 | tucuma
# Processing Record50 of Set 13 | oltu
# Processing Record1 of Set 14 | urubicha
# Processing Record2 of Set 14 | ferme-neuve
# Processing Record3 of Set 14 | oranjestad
# Processing Record4 of Set 14 | santa maria
# Processing Record5 of Set 14 | walla walla
# Processing Record6 of Set 14 | alyangula
# Processing Record7 of Set 14 | emilio carranza
# Processing Record8 of Set 14 | anopino
# Processing Record9 of Set 14 | harper
# Processing Record10 of Set 14 | tigil
# Processing Record11 of Set 14 | kungurtug
# Processing Record12 of Set 14 | price
# Processing Record13 of Set 14 | kushima
# Processing Record14 of Set 14 | livingstone
# Processing Record15 of Set 14 | ossora
# Processing Record16 of Set 14 | namatanai
# Processing Record17 of Set 14 | redcliffe
# Processing Record18 of Set 14 | mizpe ramon
# City not found. Skipping...
# Processing Record19 of Set 14 | karatu
# Processing Record20 of Set 14 | voh
# Processing Record21 of Set 14 | katangli
# Processing Record22 of Set 14 | yumen
# Processing Record23 of Set 14 | reconquista
# Processing Record24 of Set 14 | kamenetskiy
# Processing Record25 of Set 14 | cottonwood
# Processing Record26 of Set 14 | christchurch
# Processing Record27 of Set 14 | liuli
# Processing Record28 of Set 14 | kizukuri
# Processing Record29 of Set 14 | kathu
# Processing Record30 of Set 14 | shubarkuduk
# Processing Record31 of Set 14 | yinchuan
# Processing Record32 of Set 14 | nouakchott
# Processing Record33 of Set 14 | broken hill
# Processing Record34 of Set 14 | tromso
# Processing Record35 of Set 14 | taburi
# City not found. Skipping...
# Processing Record36 of Set 14 | kozhva
# Processing Record37 of Set 14 | oriximina
# Processing Record38 of Set 14 | spartanburg
# Processing Record39 of Set 14 | rungata
# City not found. Skipping...
# Processing Record40 of Set 14 | tahoua
# Processing Record41 of Set 14 | grindavik
# Processing Record42 of Set 14 | baza
# Processing Record43 of Set 14 | aleksandrov gay
# Processing Record44 of Set 14 | nakusp
# Processing Record45 of Set 14 | seymchan
# Processing Record46 of Set 14 | kerema
# Processing Record47 of Set 14 | maicao
# Processing Record48 of Set 14 | narasannapeta
# Processing Record49 of Set 14 | ilhabela
# Processing Record50 of Set 14 | vreed en hoop
# City not found. Skipping...
# Processing Record1 of Set 15 | emmett
# Processing Record2 of Set 15 | sauk rapids
# Processing Record3 of Set 15 | vanavara
# Processing Record4 of Set 15 | birnin kebbi
# Processing Record5 of Set 15 | lolua
# City not found. Skipping...
# Processing Record6 of Set 15 | bonfim
# Processing Record7 of Set 15 | tawzar
# City not found. Skipping...
# Processing Record8 of Set 15 | bogorodskoye
# Processing Record9 of Set 15 | kailua
# Processing Record10 of Set 15 | paradwip
# City not found. Skipping...
# Processing Record11 of Set 15 | bahawalpur
# Processing Record12 of Set 15 | komsomolskiy
# Processing Record13 of Set 15 | haibowan
# City not found. Skipping...
# Processing Record14 of Set 15 | novochernorechenskiy
# Processing Record15 of Set 15 | elizabeth city
# Processing Record16 of Set 15 | solnechnyy
# Processing Record17 of Set 15 | matagami
# Processing Record18 of Set 15 | camana
# Processing Record19 of Set 15 | lamu
# Processing Record20 of Set 15 | artyk
# City not found. Skipping...
# Processing Record21 of Set 15 | psebay
# Processing Record22 of Set 15 | sawtell
# Processing Record23 of Set 15 | alamosa
# Processing Record24 of Set 15 | watrous
# Processing Record25 of Set 15 | hanyang
# Processing Record26 of Set 15 | pathein
# Processing Record27 of Set 15 | mutis
# Processing Record28 of Set 15 | casablanca
# Processing Record29 of Set 15 | toliary
# City not found. Skipping...
# Processing Record30 of Set 15 | shimoda
# Processing Record31 of Set 15 | ondjiva
# Processing Record32 of Set 15 | san andres
# Processing Record33 of Set 15 | birao
# Processing Record34 of Set 15 | yingkou
# Processing Record35 of Set 15 | dingle
# Processing Record36 of Set 15 | doha
# Processing Record37 of Set 15 | shirokiy
# Processing Record38 of Set 15 | morant bay
# Processing Record39 of Set 15 | karkaralinsk
# City not found. Skipping...
# Processing Record40 of Set 15 | forio
# Processing Record41 of Set 15 | homer
# Processing Record42 of Set 15 | kudahuvadhoo
# Processing Record43 of Set 15 | kenai
# Processing Record44 of Set 15 | agadez
# Processing Record45 of Set 15 | sabang
# Processing Record46 of Set 15 | burica
# City not found. Skipping...
# Processing Record47 of Set 15 | kon tum
# Processing Record48 of Set 15 | anadyr
# Processing Record49 of Set 15 | inderborskiy
# City not found. Skipping...
# Processing Record50 of Set 15 | douentza
# Processing Record1 of Set 16 | tukrah
# Processing Record2 of Set 16 | aberystwyth
# Processing Record3 of Set 16 | manacapuru
# Processing Record4 of Set 16 | straumen
# Processing Record5 of Set 16 | poronaysk
# Processing Record6 of Set 16 | jardim
# Processing Record7 of Set 16 | toccoa
# Processing Record8 of Set 16 | solano
# Processing Record9 of Set 16 | damuc
# Processing Record10 of Set 16 | gazanjyk
# Processing Record11 of Set 16 | puerto carreno
# Processing Record12 of Set 16 | hammerfest
# Processing Record13 of Set 16 | billings
# Processing Record14 of Set 16 | kidal
# Processing Record15 of Set 16 | sitio novo do tocantins
# Processing Record16 of Set 16 | grimstad
# -----------------------------
# Data Retrieval Complete
# -----------------------------

# %%
# Convert the array of dictionaries to a Pandas DataFrame.
city_data_df = pd.DataFrame(city_data)
city_data_df.head(10)
# Out:
#               City Country      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# 0  Arraial Do Cabo      BR -22.9661  -42.0278     71.46        94          75
# 1        Cape Town      ZA -33.9258   18.4232     67.08        81           0
# 2         Souillac      MU -20.5167   57.5167     75.58        88          75
# 3           Albany      US  42.6001  -73.9662     35.10        70          48
# 4       Bredasdorp      ZA -34.5322   20.0403     63.72        82          36
# 5         Buraydah      SA  26.3260   43.9750     55.85        35           0
# 6      Clyde River      CA  70.4692  -68.5914    -25.37        68          75
# 7             Chuy      UY -33.6971  -53.4616     68.36        64          11
# 8          Margate      GB  51.3813    1.3862     49.96        78          96
# 9     Norman Wells      CA  65.2820 -126.8329    -27.36        62          75
#
#    Wind Speed Current Description
# 0        6.91                mist
# 1        3.44           clear sky
# 2        4.61       broken clouds
# 3       11.12    scattered clouds
# 4        6.91    scattered clouds
# 5        8.37           clear sky
# 6        0.00       broken clouds
# 7        7.83          few clouds
# 8        5.01     overcast clouds
# 9        3.44       broken clouds

# %%
# Create the output file (CSV).
output_data_file = "Weather_Database/WeatherPy_Database.csv"
# Export the City_Data into a CSV.
city_data_df.to_csv(output_data_file, index_label="City_ID")

# %%
# Extract relevant fields from the DataFrame for plotting.
lats = city_data_df["Lat"]
max_temps = city_data_df["Max Temp"]
humidity = city_data_df["Humidity"]
cloudiness = city_data_df["Cloudiness"]
wind_speed = city_data_df["Wind Speed"]

# %%
# Build the scatter plot for latitude vs. max temperature.
plt.scatter(lats, max_temps,
           edgecolor="black", linewidths=1, marker="o",
           alpha=0.8, label="Cities")
plt.title(f"City Latitude vs. Max Temperature "+ time.strftime("%x"))
plt.ylabel("Max Temperature (F)")
plt.xlabel("Latitude")
plt.grid(True)

# Save the figure.
plt.savefig("weather_data/Fig1.png")

# Show plot.
plt.show()

# %%
# Build the scatter plot for latitude vs. % humidity.
plt.scatter(lats, humidity,
           edgecolor="black", linewidths=1, marker="o",
           alpha=0.8, label="Cities")
plt.title(f"City Latitude vs. Humidity "+ time.strftime("%x"))
plt.ylabel("Humidity (%)")
plt.xlabel("Latitude")
plt.grid(True)

# Save the figure.
plt.savefig("weather_data/Fig2.png")

# Show plot.
plt.show()

# %%
# Build the scatter plot for latitude vs. %cloudiness.
plt.scatter(lats, cloudiness,
           edgecolor="black", linewidths=1, marker="o",
           alpha=0.8, label="Cities")
plt.title(f"City Latitude vs. Cloudiness (%) "+ time.strftime("%x"))
plt.ylabel("Cloudiness (%)")
plt.xlabel("Latitude")
plt.grid(True)

# Save the figure.
plt.savefig("weather_data/Fig3.png")

# Show plot.
plt.show()

# %%
# Build the scatter plot for latitude vs. windspeed (mph).
plt.scatter(lats, wind_speed,
           edgecolor="black", linewidths=1, marker="o",
           alpha=0.8, label="Cities")
plt.title(f"City Latitude vs. Wind Speed "+ time.strftime("%x"))
plt.ylabel("Windspeed (mph)")
plt.xlabel("Latitude")
plt.grid(True)

# Save the figure.
plt.savefig("weather_data/Fig4.png")

# Show plot.
plt.show()

# %%
# Create Northern and Southern Hemisphere DataFrames.
northern_hemi_df = city_data_df.loc[(city_data_df["Lat"] >= 0)]
southern_hemi_df = city_data_df.loc[(city_data_df["Lat"] < 0)]
northern_hemi_df

# %%
# Import linregress
from scipy.stats import linregress

# Create a function to create perform linear regression on the weather data
# and plot a regression line and the equation with the data.
def plot_linear_regression(x_values, y_values, title, y_label, text_coordinates):

    # Run regression on hemisphere weather data.
    (slope, intercept, r_value, p_value, std_err) = linregress(x_values, y_values)

    # Calculate the regression line "y values" from the slope and intercept.
    regress_values = x_values * slope + intercept
    # Get the equation of the line.
    line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))
    # Create a scatter plot and plot the regression line.
    plt.scatter(x_values,y_values)
    plt.plot(x_values,regress_values,"r")
    # Annotate the text for the line equation.
    plt.annotate(line_eq, text_coordinates, fontsize=15, color="red")
    plt.title(title)
    plt.xlabel('Latitude')
    plt.ylabel(y_label)
    plt.show()

# %%
# Linear regression max temp on the Northern Hemisphere
x_values = northern_hemi_df["Lat"]
y_values = northern_hemi_df["Max Temp"]
# Call the function.
plot_linear_regression(x_values, y_values,
                       'Linear Regression on the Northern Hemisphere \nfor Maximum Temperature', 
                       'Max Temp',(0,-40))

# %%
# Linear regression humidity on the Southern Hemisphere
x_values = southern_hemi_df["Lat"]
y_values = southern_hemi_df["Max Temp"]
# Call the function.
plot_linear_regression(x_values, y_values,
                       'Linear Regression on the Southern Hemisphere \nfor Maximum Temperature', 'Max Temp',(-50,47))

# %%
# Linear regression humidity on the Northern Hemisphere
x_values = northern_hemi_df["Lat"]
y_values = northern_hemi_df["Humidity"]
# Call the function.
plot_linear_regression(x_values, y_values,
                       'Linear Regression on the Northern Hemisphere \nfor % Humidity', 
                       '% Humidity',(40,10))

# %%
# Linear regression humidity on the Southern Hemisphere
x_values = southern_hemi_df["Lat"]
y_values = southern_hemi_df["Humidity"]
# Call the function.
plot_linear_regression(x_values, y_values,
                       'Linear Regression on the Southern Hemisphere \nfor % Humidity', 
                       '% Humidity',(-30,15))

# %%
# Linear regression cloudiness on the Northern Hemisphere
x_values = northern_hemi_df["Lat"]
y_values = northern_hemi_df["Cloudiness"]
# Call the function.
plot_linear_regression(x_values, y_values,
                       'Linear Regression on the Northern Hemisphere \nfor % Cloudiness', 
                       '% Cloudiness',(0,60))

# %%
# Linear regression cloudiness on the Northern Hemisphere
x_values = southern_hemi_df["Lat"]
y_values = southern_hemi_df["Cloudiness"]
# Call the function.
plot_linear_regression(x_values, y_values,
                       'Linear Regression on the Northern Hemisphere \nfor % Cloudiness', 
                       '% Cloudiness',(-50,25))

# %%
# Linear regression wind speed on the Northern Hemisphere
x_values = northern_hemi_df["Lat"]
y_values = northern_hemi_df["Wind Speed"]
# Call the function.
plot_linear_regression(x_values, y_values,
                       'Linear Regression on the Northern Hemisphere \nfor Wind Speed', 
                       'Wind Speed (mph)',(0,45))

# %%
# Linear regression wind speed on the Northern Hemisphere
x_values = southern_hemi_df["Lat"]
y_values = southern_hemi_df["Wind Speed"]
# Call the function.
plot_linear_regression(x_values, y_values,
                       'Linear Regression on the Northern Hemisphere \nfor Wind Speed', 
                       'Wind Speed',(0,45))

# %%
# Import the dependencies.
import pandas as pd
import gmaps
import requests
# Import the API key.
from config import gkey

# %%
# Store the CSV you saved created in part one into a DataFrame.
city_data_df = pd.read_csv("weather_data/cities.csv")
city_data_df.head()

# %%
city_data_df.dtypes

# %%
# Configure gmaps to use your Google API key.
gmaps.configure(api_key=gkey)

# Heatmap of temperature
# 1. Get the latitude and longitude.
locations = city_data_df[["Lat", "Lng"]]
# 2. Get the maximum temperature.
max_temp = city_data_df["Max Temp"]
# 3. Assign the figure variable.
fig = gmaps.figure(center=(30.0, 31.0), zoom_level=1.5)
# 4. Assign the heatmap variable.
heat_layer = gmaps.heatmap_layer(locations, weights=[max(temp, 0) for temp in max_temp], 
                                 dissipating=False, max_intensity=300, point_radius=4)
# Add the heatmap layer.
fig.add_layer(heat_layer)
# Call the figure to plot the data.
fig

# %%
# Heatmap of percent humidity
locations = city_data_df[["Lat", "Lng"]]
humidity = city_data_df["Humidity"]
fig = gmaps.figure(center=(30.0, 31.0), zoom_level=1.5)
heat_layer = gmaps.heatmap_layer(locations, weights=humidity, 
                                 dissipating=False, max_intensity=300, point_radius=4)

fig.add_layer(heat_layer)
# Call the figure to plot the data.
fig

# %%
# Heatmap of percent cloudiness
locations = city_data_df[["Lat", "Lng"]]
clouds = city_data_df["Cloudiness"]
fig = gmaps.figure(center=(30.0, 31.0), zoom_level=1.5)
heat_layer = gmaps.heatmap_layer(locations, weights=clouds, 
                                 dissipating=False, max_intensity=300, point_radius=4)

fig.add_layer(heat_layer)
# Call the figure to plot the data.
fig

# %%
# Heatmap of percent humidity
locations = city_data_df[["Lat", "Lng"]]
wind = city_data_df["Wind Speed"]
fig = gmaps.figure(center=(30.0, 31.0), zoom_level=1.5)
heat_layer = gmaps.heatmap_layer(locations, weights=wind, 
                                 dissipating=False, max_intensity=300, point_radius=4)

fig.add_layer(heat_layer)
# Call the figure to plot the data.
fig

# %%
# Ask the customer to add a minimum and maximum temperature value.
min_temp = float(input("What is the minimum temperature you would like for your trip? "))
max_temp = float(input("What is the maximum temperature you would like for your trip? "))

# Filter the dataset to find the cities that fit the criteria.
preferred_cities_df = city_data_df.loc[(city_data_df["Max Temp"] <= max_temp) & \
                                       (city_data_df["Max Temp"] >= min_temp)]
preferred_cities_df.count()
preferred_cities_df.dropna()
preferred_cities_df.head(10)

# %%
# Create DataFrame called hotel_df to store hotel names along with city, country, max temp, and coordinates.
hotel_df = preferred_cities_df[["City", "Country", "Max Temp", "Lat", "Lng"]].copy()
hotel_df["Hotel Name"] = ""
hotel_df.head(10)

# %%
# Set parameters to search for a hotel.
params = {
    "radius": 5000,
    "type": "lodging",
    "key": gkey
}`
